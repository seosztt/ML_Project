# %%
import pandas as pd
path='C:/Users/USER/datasets'

csp=pd.read_csv(path + '/CSP/daily_onion_wholesale.csv', encoding= 'cp949')

# %%
csp[['market','corporation']][:20]
# Out:
#     market corporation
# 0   대구북부도매        효성청과
# 1   대구북부도매        효성청과
# 2   대구북부도매        효성청과
# 3   대구북부도매        효성청과
# 4   대구북부도매      대구중앙청과
# 5   서울강서도매        농협강서
# 6   서울강서도매        강서청과
# 7   광주각화도매      광주원예농협
# 8   인천삼산도매        경인농산
# 9   인천삼산도매      인천원협삼산
# 10  인천삼산도매        부평농산
# 11  인천삼산도매        부평농산
# 12  인천삼산도매      인천원협삼산
# 13  인천삼산도매        부평농산
# 14  인천삼산도매      인천원협삼산
# 15  부산반여도매        농협반여
# 16  부산반여도매        농협반여
# 17  부산반여도매        농협반여
# 18  대전노은도매      대전중앙청과
# 19  대전노은도매        대전원협
