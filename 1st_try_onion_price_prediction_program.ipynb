# %% [markdown]
# <a href="https://colab.research.google.com/github/seosztt/ML_Project/blob/master/1st_try_onion_price_prediction_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # preprocess

# %%
import pandas as pd

price = pd.read_csv('/content/drive/MyDrive/2조/datasets/전처리/5/price2.csv')
amount = pd.read_csv('/content/drive/MyDrive/2조/datasets/전처리/5/amount2.csv')
top = pd.read_csv('/content/drive/MyDrive/2조/datasets/전처리/5/시군산지_기후관측소기준 TOP39.csv')
inout = pd.read_csv('/content/drive/MyDrive/2조/datasets/전처리/5/inout.csv')
weather = pd.read_csv('/content/drive/MyDrive/2조/datasets/전처리/5/weather2.csv')

# %%
PA = pd.merge(price, amount, on = ['연', '광역산지'])
PA.head()
# Out:
#        품종      시장    법인 광역산지 시군산지  도매가격(원/kg)   연   월  재배면적  재배비율     생산량
# 0  양파(일반)  대구북부도매  대양청과   경북   영천      793.00  21  10  2365  8098  191509
# 1  양파(일반)  대구북부도매  효성청과   경북   의성      803.03  21  10  2365  8098  191509
# 2  양파(일반)  대구북부도매  효성청과   경북   영천      843.43  21  10  2365  8098  191509
# 3  양파(일반)  대구북부도매  대양청과   경북   성주      781.82  21  10  2365  8098  191509
# 4  양파(일반)  대구북부도매  대양청과   경북   고령      800.00  21  10  2365  8098  191509

# %%
TOP39 = PA[PA['시군산지'].str.contains('무안|함평|창녕|신안|합천|제주|구리|함양|영천|고흥|해남|\
       |고령|의성|김천|논산|부안|문경|달성|군위|서귀포|고창|완주|\
       |의령|서산|익산|장흥|경산|밀양|창원의창|대구중구|영주|안동|\
       |여수|나주|광주서구|영암|연제|구미|거창')]
idx_천안동남 = TOP39[TOP39['시군산지'] == '천안동남'].index
TOP39.drop(idx_천안동남, inplace=True)

# %%
PAT = pd.merge(TOP39, top, on = ['시군산지'])
PAT.head()
# Out:
#        품종      시장        법인 광역산지 시군산지  ...   월  재배면적  재배비율     생산량  기후관측소기준
# 0  양파(일반)  대구북부도매      대양청과   경북   영천  ...  10  2365  8098  191509       영천
# 1  양파(일반)  대구북부도매      효성청과   경북   영천  ...  10  2365  8098  191509       영천
# 2      기타    포항도매  대구경북능금원협   경북   영천  ...  10  2365  8098  191509       영천
# 3  양파(일반)  대구북부도매      대양청과   경북   영천  ...   9  2365  8098  191509       영천
# 4  양파(일반)  대구북부도매      효성청과   경북   영천  ...   9  2365  8098  191509       영천
#
# [5 rows x 12 columns]

# %%
PAT.columns = ['kind', 'market', 'corp', 'wide', 'city', 'price', 'year', 'month', 'area', 'ratio', 'amount', 'weather']
PAT.head()
# Out:
#      kind  market      corp wide city  ...  month  area  ratio  amount  weather
# 0  양파(일반)  대구북부도매      대양청과   경북   영천  ...     10  2365   8098  191509       영천
# 1  양파(일반)  대구북부도매      효성청과   경북   영천  ...     10  2365   8098  191509       영천
# 2      기타    포항도매  대구경북능금원협   경북   영천  ...     10  2365   8098  191509       영천
# 3  양파(일반)  대구북부도매      대양청과   경북   영천  ...      9  2365   8098  191509       영천
# 4  양파(일반)  대구북부도매      효성청과   경북   영천  ...      9  2365   8098  191509       영천
#
# [5 rows x 12 columns]

# %%
PAT[PAT['weather']=='영광']
# Out:
#          kind  market    corp wide city  ...  month   area  ratio  amount  weather
# 19307    저장양파  서울가락도매    한국청과   전남   함평  ...     10   5743   7883  452737       영광
# 19308    저장양파  서울가락도매    동화청과   전남   함평  ...     10   5743   7883  452737       영광
# 19309    만생양파  서울가락도매    서울청과   전남   함평  ...     10   5743   7883  452737       영광
# 19310    만생양파  광주각화도매  광주중앙청과   전남   함평  ...     10   5743   7883  452737       영광
# 19311  양파(일반)  서울강서도매    농협강서   전남   함평  ...      9   5743   7883  452737       영광
# ...       ...     ...     ...  ...  ...  ...    ...    ...    ...     ...      ...
# 20998    저장양파  서울가락도매    동화청과   전남   함평  ...      2  10124   5730  580151       영광
# 20999      기타  서울가락도매    중앙청과   전남   함평  ...      1  10124   5730  580151       영광
# 21000      기타  서울강서도매    서부청과   전남   함평  ...      1  10124   5730  580151       영광
# 21001    저장양파  서울가락도매    한국청과   전남   함평  ...      1  10124   5730  580151       영광
# 21002    저장양파  서울가락도매    동화청과   전남   함평  ...      1  10124   5730  580151       영광
#
# [1696 rows x 12 columns]

# %%
PATI = pd.merge(PAT, inout, on = ['year', 'month'])
PATI.head()
# Out:
#      kind  market      corp wide city  ...  ratio  amount  weather       inn   out
# 0  양파(일반)  대구북부도매      대양청과   경북   영천  ...   8098  191509       영천  5213.902  7.88
# 1  양파(일반)  대구북부도매      효성청과   경북   영천  ...   8098  191509       영천  5213.902  7.88
# 2      기타    포항도매  대구경북능금원협   경북   영천  ...   8098  191509       영천  5213.902  7.88
# 3  양파(일반)  대구북부도매      효성청과   경북   의성  ...   8098  191509       의성  5213.902  7.88
# 4  양파(일반)  부산엄궁도매      부산청과   경북   의성  ...   8098  191509       의성  5213.902  7.88
#
# [5 rows x 14 columns]

# %%
PATIW = pd.merge(PATI, weather, on = ['year', 'weather'])
PATIW.head()
# Out:
#      kind  market      corp wide city  ...  SUN_8  SUN_9  SUN_10  SUN_11  SUN_12
# 0  양파(일반)  대구북부도매      대양청과   경북   영천  ...  190.0  140.2   198.3   160.8   172.4
# 1  양파(일반)  대구북부도매      효성청과   경북   영천  ...  190.0  140.2   198.3   160.8   172.4
# 2      기타    포항도매  대구경북능금원협   경북   영천  ...  190.0  140.2   198.3   160.8   172.4
# 3  양파(일반)  대구북부도매      대양청과   경북   영천  ...  190.0  140.2   198.3   160.8   172.4
# 4  양파(일반)  대구북부도매      효성청과   경북   영천  ...  190.0  140.2   198.3   160.8   172.4
#
# [5 rows x 74 columns]

# %%
PATIW.groupby(['city'])['kind'].agg(**{
    'most_common_value':lambda x:x.mode()
}).reset_index()
# Out:
#     city most_common_value
# 0     거창            양파(일반)
# 1     경산            양파(일반)
# 2     고령            양파(일반)
# 3     고창            양파(일반)
# 4     고흥            양파(일반)
# 5   광주서구                기타
# 6     구리                기타
# 7     구미            양파(일반)
# 8     군위            양파(일반)
# 9     김천            양파(일반)
# 10    나주                기타
# 11    논산            양파(일반)
# 12    달성            양파(일반)
# 13  대구중구            양파(일반)
# 14    무안            양파(일반)
# 15    문경            양파(일반)
# 16    밀양            양파(일반)
# 17    부안                기타
# 18   서귀포            양파(일반)
# 19    서산            양파(일반)
# 20    신안            양파(일반)
# 21    안동            양파(일반)
# 22    여수            양파(일반)
# 23    연제            양파(일반)
# 24    영암            양파(일반)
# 25    영주                기타
# 26    영천            양파(일반)
# 27    완주                기타
# 28    의령            양파(일반)
# 29    의성            양파(일반)
# 30    익산            양파(일반)
# 31    장흥            양파(일반)
# 32    제주            양파(일반)
# 33    창녕            양파(일반)
# 34  창원의창            양파(일반)
# 35    함양            양파(일반)
# 36    합천            양파(일반)
# 37    해남            양파(일반)

# %%
PATIW.groupby(['city'])['market'].agg(**{
    'most_common_value':lambda x:x.mode()
}).reset_index()
# Out:
#     city most_common_value
# 0     거창            대구북부도매
# 1     경산            대구북부도매
# 2     고령            대구북부도매
# 3     고창            서울가락도매
# 4     고흥              순천도매
# 5   광주서구            광주서부도매
# 6     구리              구리도매
# 7     구미              구미도매
# 8     군위            대구북부도매
# 9     김천            대구북부도매
# 10    나주            광주서부도매
# 11    논산            인천삼산도매
# 12    달성            대구북부도매
# 13  대구중구            대구북부도매
# 14    무안            서울가락도매
# 15    문경            인천남촌도매
# 16    밀양            부산반여도매
# 17    부안            서울가락도매
# 18   서귀포            서울가락도매
# 19    서산            서울가락도매
# 20    신안            서울가락도매
# 21    안동            대구북부도매
# 22    여수              순천도매
# 23    연제            부산반여도매
# 24    영암            서울가락도매
# 25    영주            서울가락도매
# 26    영천            대구북부도매
# 27    완주              전주도매
# 28    의령            부산엄궁도매
# 29    의성            대구북부도매
# 30    익산              익산도매
# 31    장흥            광주각화도매
# 32    제주            서울가락도매
# 33    창녕            대구북부도매
# 34  창원의창            창원팔용도매
# 35    함양            서울가락도매
# 36    합천            대구북부도매
# 37    해남            광주각화도매

# %%
PATIW.groupby(['city'])['corp'].agg(**{
    'most_common_value':lambda x:x.mode()
}).reset_index()
# Out:
#     city most_common_value
# 0     거창              대양청과
# 1     경산              부산청과
# 2     고령              대양청과
# 3     고창              한국청과
# 4     고흥            순천남도청과
# 5   광주서구            광주원예농협
# 6     구리              구리청과
# 7     구미              구미농협
# 8     군위              대양청과
# 9     김천              대양청과
# 10    나주              광주청과
# 11    논산            대전중앙청과
# 12    달성              대양청과
# 13  대구중구              대양청과
# 14    무안              한국청과
# 15    문경             인천농산물
# 16    밀양              부산청과
# 17    부안              중앙청과
# 18   서귀포             인천농산물
# 19    서산              중앙청과
# 20    신안              동화청과
# 21    안동              대양청과
# 22    여수            순천남도청과
# 23    연제              동부청과
# 24    영암              한국청과
# 25    영주             인터넷청과
# 26    영천              효성청과
# 27    완주              전주원협
# 28    의령              부산청과
# 29    의성              대양청과
# 30    익산            익산원예농협
# 31    장흥              광주청과
# 32    제주              서부청과
# 33    창녕              부산청과
# 34  창원의창            창원청과시장
# 35    함양              중앙청과
# 36    합천              대양청과
# 37    해남              호남청과

# %%
PATIW.groupby(['city','corp']).count().iloc[:50]
# Out:
#                kind  market  wide  price  ...  SUN_9  SUN_10  SUN_11  SUN_12
# city corp                                 ...
# 거창   경인농산        16      16    16     16  ...     16      16      16      16
#      광주원예농협       2       2     2      2  ...      2       2       2       2
#      광주중앙청과       2       2     2      2  ...      2       2       2       2
#      광주청과         1       1     1      1  ...      1       1       1       1
#      구리청과         1       1     1      1  ...      1       1       1       1
#      구미중앙청과       1       1     1      1  ...      1       1       1       1
#      농협가락         6       6     6      6  ...      6       6       6       6
#      농협강서         5       5     5      5  ...      5       5       5       5
#      농협구리        12      12    12     12  ...     12      12      12      12
#      농협대전        13      13    13     13  ...     13      13      13      13
#      농협반여         6       6     6      6  ...      6       6       6       6
#      농협부산         4       4     4      4  ...      4       4       4       4
#      농협북대구        2       2     2      2  ...      2       2       2       2
#      농협창원         3       3     3      3  ...      3       3       3       3
#      대구경북원예농협     4       4     4      4  ...      4       4       4       4
#      대구중앙청과      10      10    10     10  ...     10      10      10      10
#      대양청과        38      38    38     38  ...     38      38      38      38
#      대전원협         6       6     6      6  ...      6       6       6       6
#      대전중앙청과      13      13    13     13  ...     13      13      13      13
#      대전청과         4       4     4      4  ...      4       4       4       4
#      덕풍청과         2       2     2      2  ...      2       2       2       2
#      동부청과         3       3     3      3  ...      3       3       3       3
#      동화청과         4       4     4      4  ...      4       4       4       4
#      두레청과        10      10    10     10  ...     10      10      10      10
#      마산청과시장       2       2     2      2  ...      2       2       2       2
#      부산중앙청과       6       6     6      6  ...      6       6       6       6
#      부산청과         8       8     8      8  ...      8       8       8       8
#      부평농산         1       1     1      1  ...      1       1       1       1
#      서부청과         5       5     5      5  ...      5       5       5       5
#      서울청과         1       1     1      1  ...      1       1       1       1
#      순천남도청과       1       1     1      1  ...      1       1       1       1
#      순천원협         3       3     3      3  ...      3       3       3       3
#      안양농산물        2       2     2      2  ...      2       2       2       2
#      인천농산물       21      21    21     21  ...     21      21      21      21
#      인천원예농협남촌     3       3     3      3  ...      3       3       3       3
#      인천원협삼산       8       8     8      8  ...      8       8       8       8
#      인터넷청과       12      12    12     12  ...     12      12      12      12
#      중앙청과        11      11    11     11  ...     11      11      11      11
#      진주농협         5       5     5      5  ...      5       5       5       5
#      진주중앙청과      14      14    14     14  ...     14      14      14      14
#      창원원협         4       4     4      4  ...      4       4       4       4
#      창원청과시장       3       3     3      3  ...      3       3       3       3
#      충북원협청주       1       1     1      1  ...      1       1       1       1
#      한국청과        10      10    10     10  ...     10      10      10      10
#      항도청과         8       8     8      8  ...      8       8       8       8
#      효성청과        23      23    23     23  ...     23      23      23      23
# 경산   강서청과         7       7     7      7  ...      7       7       7       7
#      경기청과         6       6     6      6  ...      6       6       6       6
#      광주원예농협       1       1     1      1  ...      1       1       1       1
#      광주중앙청과       2       2     2      2  ...      2       2       2       2
#
# [50 rows x 72 columns]

# %%
PATIW.groupby(['city','market']).count().iloc[:50]
# Out:
#              kind  corp  wide  price  ...  SUN_9  SUN_10  SUN_11  SUN_12
# city market                           ...
# 거창   광주각화도매     5     5     5      5  ...      5       5       5       5
#      광주서부도매    10    10    10     10  ...     10      10      10      10
#      구리도매      25    25    25     25  ...     25      25      25      25
#      구미도매       1     1     1      1  ...      1       1       1       1
#      대구북부도매    77    77    77     77  ...     77      77      77      77
#      대전노은도매    19    19    19     19  ...     19      19      19      19
#      대전오정도매    17    17    17     17  ...     17      17      17      17
#      부산반여도매    15    15    15     15  ...     15      15      15      15
#      부산엄궁도매    20    20    20     20  ...     20      20      20      20
#      서울가락도매    32    32    32     32  ...     32      32      32      32
#      서울강서도매    10    10    10     10  ...     10      10      10      10
#      순천도매       4     4     4      4  ...      4       4       4       4
#      안양도매       2     2     2      2  ...      2       2       2       2
#      인천남촌도매    26    26    26     26  ...     26      26      26      26
#      인천삼산도매    25    25    25     25  ...     25      25      25      25
#      진주도매      19    19    19     19  ...     19      19      19      19
#      창원내서도매     6     6     6      6  ...      6       6       6       6
#      창원팔용도매     6     6     6      6  ...      6       6       6       6
#      청주도매       1     1     1      1  ...      1       1       1       1
# 경산   광주각화도매     8     8     8      8  ...      8       8       8       8
#      광주서부도매    10    10    10     10  ...     10      10      10      10
#      구리도매      43    43    43     43  ...     43      43      43      43
#      대구북부도매   152   152   152    152  ...    152     152     152     152
#      대전노은도매    21    21    21     21  ...     21      21      21      21
#      대전오정도매    12    12    12     12  ...     12      12      12      12
#      부산반여도매    66    66    66     66  ...     66      66      66      66
#      부산엄궁도매    86    86    86     86  ...     86      86      86      86
#      서울가락도매    28    28    28     28  ...     28      28      28      28
#      서울강서도매    12    12    12     12  ...     12      12      12      12
#      수원도매      23    23    23     23  ...     23      23      23      23
#      순천도매       3     3     3      3  ...      3       3       3       3
#      안산도매       4     4     4      4  ...      4       4       4       4
#      울산도매      20    20    20     20  ...     20      20      20      20
#      인천남촌도매     9     9     9      9  ...      9       9       9       9
#      인천삼산도매    18    18    18     18  ...     18      18      18      18
#      창원내서도매     4     4     4      4  ...      4       4       4       4
#      창원팔용도매    13    13    13     13  ...     13      13      13      13
#      천안도매       2     2     2      2  ...      2       2       2       2
#      춘천도매       6     6     6      6  ...      6       6       6       6
#      충주도매       1     1     1      1  ...      1       1       1       1
#      포항도매      11    11    11     11  ...     11      11      11      11
# 고령   광주서부도매     6     6     6      6  ...      6       6       6       6
#      구리도매      48    48    48     48  ...     48      48      48      48
#      구미도매       2     2     2      2  ...      2       2       2       2
#      대구북부도매   223   223   223    223  ...    223     223     223     223
#      대전노은도매    33    33    33     33  ...     33      33      33      33
#      대전오정도매    19    19    19     19  ...     19      19      19      19
#      부산반여도매    37    37    37     37  ...     37      37      37      37
#      부산엄궁도매    48    48    48     48  ...     48      48      48      48
#      서울가락도매   103   103   103    103  ...    103     103     103     103
#
# [50 rows x 72 columns]

# %% [markdown]
# ## save

# %%
PATIW.to_csv('/content/drive/MyDrive/2조/datasets/전처리/initial_dataset_for_program.csv')

# %% [markdown]
# # first program
# 컬럼 별 예측값 알고리즘
# - kind, corp, market : groupby city 최빈값
# - 2021년 10월 11월 12월의 날씨 정보 : 각 월 해당 city의 2014~20년 값의 평균
#
# 변수 선택
# - feature_del 리스트의 42개 변수 제외

# %% [markdown]
# ## ReadData

# %%
import pandas as pd

CSP=pd.read_csv('/content/drive/MyDrive/2조/datasets/전처리/initial_dataset_for_program.csv')

CSP.drop(columns=['Unnamed: 0'],inplace=True)

# %%
CSP
# Out:
#          kind  market      corp wide city  ...  SUN_8  SUN_9  SUN_10  SUN_11  SUN_12
# 0      양파(일반)  대구북부도매      대양청과   경북   영천  ...  190.0  140.2   198.3   160.8   172.4
# 1      양파(일반)  대구북부도매      효성청과   경북   영천  ...  190.0  140.2   198.3   160.8   172.4
# 2          기타    포항도매  대구경북능금원협   경북   영천  ...  190.0  140.2   198.3   160.8   172.4
# 3      양파(일반)  대구북부도매      대양청과   경북   영천  ...  190.0  140.2   198.3   160.8   172.4
# 4      양파(일반)  대구북부도매      효성청과   경북   영천  ...  190.0  140.2   198.3   160.8   172.4
# ...       ...     ...       ...  ...  ...  ...    ...    ...     ...     ...     ...
# 23786    조생양파  대구북부도매      대양청과   전남   여수  ...  301.2  130.8   126.1   182.2   193.2
# 23787      기타  서울강서도매      강서청과   제주  서귀포  ...  282.7  126.0    97.9   155.1   162.5
# 23788    저장양파  서울가락도매      동화청과   제주  서귀포  ...  282.7  126.0    97.9   155.1   162.5
# 23789    조생양파  서울가락도매      한국청과   제주  서귀포  ...  282.7  126.0    97.9   155.1   162.5
# 23790    조생양파  대구북부도매      대양청과   제주  서귀포  ...  282.7  126.0    97.9   155.1   162.5
#
# [23791 rows x 74 columns]

# %% [markdown]
# ## LabelEncoder

# %%
feature_LE=['market','corp','wide']

# %%
from sklearn.preprocessing import LabelEncoder

LE=LabelEncoder()

for i in feature_LE:
    CSP[i]=LE.fit_transform(CSP[i])

# %% [markdown]
# ### city

# %%
LE_city=LabelEncoder()

CSP['city']=LE_city.fit_transform(CSP['city'])

# %%
LE_city.classes_
# Out:
# array(['거창', '경산', '고령', '고창', '고흥', '광주서구', '구리', '구미', '군위', '김천', '나주',
#        '논산', '달성', '대구중구', '무안', '문경', '밀양', '부안', '서귀포', '서산', '신안',
#        '안동', '여수', '연제', '영암', '영주', '영천', '완주', '의령', '의성', '익산', '장흥',
#        '제주', '창녕', '창원의창', '함양', '합천', '해남'], dtype=object)

# %%
def get_integer_mapping(le):
    '''
    Return a dict mapping labels to their integer values
    from an SKlearn LabelEncoder
    le = a fitted SKlearn LabelEncoder
    '''
    res = {}
    for cl in le.classes_:
        res.update({cl:le.transform([cl])[0]})

    return res

# %%
LE_city_mapping=get_integer_mapping(LE_city)

# %%
LE_city_mapping['경산']
# Out:
# 1

# %% [markdown]
# ### kind

# %%
LE_kind=LabelEncoder()

CSP['kind']=LE_kind.fit_transform(CSP['kind'])

# %%
LE_kind.classes_
# Out:
# array(['기타', '깐양파', '만생양파', '양파(수입)', '양파(일반)', '양파(임시)', '자주양파', '저장양파',
#        '조생양파', '중만생양파', '중생양파'], dtype=object)

# %%
LE_kind_mapping=get_integer_mapping(LE_kind)

# %%
LE_kind_mapping['깐양파']
# Out:
# 1

# %% [markdown]
# ## MinMaxSclaler

# %%
feature_MMS=['area','ratio','amount','inn','out']

# %%
from sklearn.preprocessing import MinMaxScaler
MMS=MinMaxScaler(feature_range=(0,100))

CSP[feature_MMS]=MMS.fit_transform(CSP[feature_MMS])

# %%
CSP
# Out:
#        kind  market  corp  wide  city  ...  SUN_8  SUN_9  SUN_10  SUN_11  SUN_12
# 0         4       5    23     2    26  ...  190.0  140.2   198.3   160.8   172.4
# 1         4       5    79     2    26  ...  190.0  140.2   198.3   160.8   172.4
# 2         0      31    20     2    26  ...  190.0  140.2   198.3   160.8   172.4
# 3         4       5    23     2    26  ...  190.0  140.2   198.3   160.8   172.4
# 4         4       5    79     2    26  ...  190.0  140.2   198.3   160.8   172.4
# ...     ...     ...   ...   ...   ...  ...    ...    ...     ...     ...     ...
# 23786     8       5    23     6    22  ...  301.2  130.8   126.1   182.2   193.2
# 23787     0      11     1     8    18  ...  282.7  126.0    97.9   155.1   162.5
# 23788     7      10    30     8    18  ...  282.7  126.0    97.9   155.1   162.5
# 23789     8      10    75     8    18  ...  282.7  126.0    97.9   155.1   162.5
# 23790     8       5    23     8    18  ...  282.7  126.0    97.9   155.1   162.5
#
# [23791 rows x 74 columns]

# %% [markdown]
# ## maping frame

# %%
kind_map=CSP.groupby(['city'])['kind'].agg(**{
    'kind':lambda x:x.mode()
}).reset_index()

market_map=CSP.groupby(['city'])['market'].agg(**{
    'market':lambda x:x.mode()
}).reset_index()

corp_map=CSP.groupby(['city'])['corp'].agg(**{
    'corp':lambda x:x.mode()
}).reset_index()

wide_map=CSP.groupby(['city'])['wide'].agg(**{
    'wide':lambda x:x.mode()
}).reset_index()

# %%
maping_frame = pd.merge(kind_map, market_map, on = ['city'])
maping_frame = pd.merge(maping_frame, corp_map, on = ['city'])
maping_frame = pd.merge(maping_frame, wide_map, on = ['city'])
maping_frame

# %%
feaiw = pd.read_csv('/content/drive/MyDrive/2조/datasets/전처리/5/future/feaiw.csv')
future = pd.read_csv('/content/drive/MyDrive/2조/datasets/전처리/5/future/future.csv', encoding='CP949')
weather3 = pd.read_csv('/content/drive/MyDrive/2조/datasets/전처리/5/future/weather3.csv')

# %%
feaiw
# Out:
#      weather  kind  year  month  ...  SUN_9      SUN_10      SUN_11      SUN_12
# 0         영천     4    21     12  ...  140.2  198.300000  160.800000  172.400000
# 1         영천     0    21     12  ...  140.2  198.300000  160.800000  172.400000
# 2         영천     7    21     12  ...  140.2  198.300000  160.800000  172.400000
# 3         영천     6    21     12  ...  140.2  198.300000  160.800000  172.400000
# 4         영천     4    21     11  ...  140.2  198.300000  160.800000  172.400000
# ...      ...   ...   ...    ...  ...    ...         ...         ...         ...
# 1722      제주     8    22      3  ...  129.3  164.377778  121.444444   75.866667
# 1723      제주     6    22      3  ...  129.3  164.377778  121.444444   75.866667
# 1724      제주     5    22      3  ...  129.3  164.377778  121.444444   75.866667
# 1725      제주     6    22      2  ...  129.3  164.377778  121.444444   75.866667
# 1726      제주     0    22      1  ...  129.3  164.377778  121.444444   75.866667
#
# [1727 rows x 67 columns]

# %%
future
# Out:
#      weather  kind  wide  year  month
# 0         영천     4     2    21     12
# 1         영천     0     2    21     12
# 2         영천     7     2    21     12
# 3         영천     6     2    21     12
# 4         영천     4     2    21     11
# ...      ...   ...   ...   ...    ...
# 1722      여수     7     6    22      3
# 1723      여수     2     6    22      3
# 1724      여수     8     6    22      3
# 1725      여수     6     6    22      3
# 1726      여수     5     6    22      3
#
# [1727 rows x 5 columns]

# %%
weather3
# Out:
#     weather  AT_1  AT_2  AT_3  ...      SUN_10      SUN_11      SUN_12  year
# 0        강릉  -0.1   0.4   5.7  ...  232.300000  203.600000  194.900000    13
# 1        강릉  -0.5   1.8   7.4  ...  193.500000  214.300000  197.900000    14
# 2        강릉   2.3   1.3   8.3  ...  206.100000  173.500000  227.900000    15
# 3        강릉   2.2   3.1   8.2  ...  255.400000   97.700000  174.200000    16
# 4        강릉   0.4   1.9   7.9  ...  151.300000  189.800000  183.900000    17
# ..      ...   ...   ...   ...  ...         ...         ...         ...   ...
# 941     흑산도   4.0   4.0   6.5  ...  174.700000  177.300000  106.900000    18
# 942     흑산도   2.0   2.2   6.6  ...  207.300000  171.700000   80.000000    19
# 943     흑산도   4.2   4.3   7.9  ...  219.600000  164.400000  118.400000    20
# 944     흑산도   6.0   6.3   8.1  ...  206.900000  143.500000  112.400000    21
# 945     흑산도   4.5   6.4   9.0  ...  205.455556  149.844444  110.933333    22
#
# [946 rows x 62 columns]

# %% [markdown]
# ## delete features

# %%
feature_del=['HT_2', 'HT_3', 'RAIN_4', 'HT_12', 'HT_1', 'LT_5', 'RAIN_12', 'RAIN_5', 'SUN_6', 'AT_4', 'AT_8', 'RAIN_1', 'SUN_3', 'AT_3', 'LT_9', 'SUN_12', 'SUN_8', 'AT_6', 'AT_5', 'RAIN_9', 'RAIN_2', 'SUN_9', 'AT_9', 'HT_11', 'HT_6', 'HT_5', 'LT_3', 'LT_7', 'HT_8', 'LT_4', 'LT_12', 'HT_4', 'LT_8', 'AT_11', 'LT_6', 'AT_2', 'HT_9', 'LT_11', 'LT_1', 'LT_10', 'RAIN_11', 'weather']

len(feature_del)
# Out:
# 42

# %%
CSP.drop(columns=feature_del, inplace=True)

# %%
CSP
# Out:
#        kind  market  corp  wide  city  ...  SUN_4  SUN_5  SUN_7  SUN_10  SUN_11
# 0         4       5    23     2    26  ...  258.5  228.3   93.8   198.3   160.8
# 1         4       5    79     2    26  ...  258.5  228.3   93.8   198.3   160.8
# 2         0      31    20     2    26  ...  258.5  228.3   93.8   198.3   160.8
# 3         4       5    23     2    26  ...  258.5  228.3   93.8   198.3   160.8
# 4         4       5    79     2    26  ...  258.5  228.3   93.8   198.3   160.8
# ...     ...     ...   ...   ...   ...  ...    ...    ...    ...     ...     ...
# 23786     8       5    23     6    22  ...  192.1  247.5  221.2   126.1   182.2
# 23787     0      11     1     8    18  ...  180.6  189.1  176.7    97.9   155.1
# 23788     7      10    30     8    18  ...  180.6  189.1  176.7    97.9   155.1
# 23789     8      10    75     8    18  ...  180.6  189.1  176.7    97.9   155.1
# 23790     8       5    23     8    18  ...  180.6  189.1  176.7    97.9   155.1
#
# [23791 rows x 32 columns]

# %% [markdown]
# ## Input city&month

# %%
print('2022년 몇 월의 가격을 예측하겠습니까: ')
month=int(input())

print('양파 가격을 예측할 도시를 따옴표 없이 입력하세요: ')
print('도시 목록: ', LE_city.classes_)
city=input()

city_num=LE_city_mapping[city]
# Out:
# 2022년 몇 월의 가격을 예측하겠습니까:
# 2
# 양파 가격을 예측할 도시를 입력하세요:
# 도시 목록:  ['거창' '경산' '고령' '고창' '고흥' '광주서구' '구리' '구미' '군위' '김천' '나주' '논산' '달성' '대구중구'
#  '무안' '문경' '밀양' '부안' '서귀포' '서산' '신안' '안동' '여수' '연제' '영암' '영주' '영천' '완주'
#  '의령' '의성' '익산' '장흥' '제주' '창녕' '창원의창' '함양' '합천' '해남']
# 서산
# 양파의 종류를 입력하세요:
# 양파 종류 목록:  ['기타' '깐양파' '만생양파' '양파(수입)' '양파(일반)' '양파(임시)' '자주양파' '저장양파' '조생양파' '중만생양파'
#  '중생양파']
# 깐양파

# %%
X_input=maping_frame[maping_frame['city']==city_num]

# %%
X_input
# Out:
#     city  kind  market  corp  wide
# 19    19     4      10    60     9

# %%
result
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
X_train=CSP.drop(columns=['price'])

y_train=CSP['price']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

RF=RandomForestRegressor(n_estimators = 2000,
                            max_depth = 5,
                            criterion ='mse',
                            n_jobs = -1,
                            random_state = 2045)

scores=cross_val_score(RF,
                       X_train,
                       y_train,
                       scoring='neg_mean_squared_error',
                       cv=5)

# %%
result=pd.DataFrame()
result.columns=['도시','월','도매가격(원/kg)']
result.append()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-277-ec8c5b079536> in <module>()
#       1 result=pd.DataFrame()
# ----> 2 result.columns=['city','month','price']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5152         try:
#    5153             object.__getattribute__(self, name)
# -> 5154             return object.__setattr__(self, name, value)
#    5155         except AttributeError:
#    5156             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# --> 564         self._mgr.set_axis(axis, labels)
#     565         self._clear_item_cache()
#     566
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     225         if new_len != old_len:
#     226             raise ValueError(
# --> 227                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     228                 f"values have {new_len} elements"
#     229             )
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 3 elements
