# %%
import pandas as pd
path='C:/Users/USER/datasets'

X=pd.read_csv(path + '/CSP/public_data/train_AT_TSALET_ALL/AT_TSALET_ALL_201601.csv')
y=pd.read_csv(path + '/CSP/public_data/train.csv')

# %%
corr=y.corr()

# %%
corr.loc[:,'캠벨얼리_거래량(kg)']
# Out:
# 배추_거래량(kg)        0.225324
# 배추_가격(원/kg)       0.509896
# 무_거래량(kg)         0.197582
# 무_가격(원/kg)        0.330408
# 양파_거래량(kg)        0.061091
# 양파_가격(원/kg)       0.111787
# 건고추_거래량(kg)       0.029755
# 건고추_가격(원/kg)      0.196223
# 마늘_거래량(kg)       -0.100331
# 마늘_가격(원/kg)       0.271193
# 대파_거래량(kg)        0.144913
# 대파_가격(원/kg)       0.331799
# 얼갈이배추_거래량(kg)     0.327398
# 얼갈이배추_가격(원/kg)    0.498008
# 양배추_거래량(kg)       0.241846
# 양배추_가격(원/kg)      0.213008
# 깻잎_거래량(kg)        0.259818
# 깻잎_가격(원/kg)       0.301252
# 시금치_거래량(kg)      -0.301634
# 시금치_가격(원/kg)      0.753805
# 미나리_거래량(kg)      -0.143737
# 미나리_가격(원/kg)      0.429964
# 당근_거래량(kg)        0.154368
# 당근_가격(원/kg)       0.246861
# 파프리카_거래량(kg)      0.080646
# 파프리카_가격(원/kg)     0.271180
# 새송이_거래량(kg)       0.247870
# 새송이_가격(원/kg)      0.287776
# 팽이버섯_거래량(kg)      0.179540
# 팽이버섯_가격(원/kg)     0.319773
# 토마토_거래량(kg)       0.021108
# 토마토_가격(원/kg)      0.177076
# 청상추_거래량(kg)       0.180250
# 청상추_가격(원/kg)      0.533085
# ...

# %%
y.iloc[-30:,-4:]
# Out:
#       캠벨얼리_거래량(kg)  캠벨얼리_가격(원/kg)  샤인마스캇_거래량(kg)  샤인마스캇_가격(원/kg)
# 1703           0.0            0.0            0.0             0.0
# 1704      676035.4         3872.0        88006.2         12433.0
# 1705      606531.4         3752.0        90299.7         12148.0
# 1706      531823.4         3703.0        81452.4         11981.0
# 1707      342894.5         3881.0        55252.0         12224.0
# 1708      313419.2         4341.0        56609.5         12519.0
# 1709      604100.4         3992.0       106609.5         12040.0
# 1710           0.0            0.0            0.0             0.0
# 1711      447623.4         4009.0        80482.7         12762.0
# 1712      340838.0         4047.0        63824.6         12371.0
# 1713      517887.5         3905.0       103245.6         11866.0
# 1714      553752.5         3734.0       118111.1         11220.0
# 1715      551487.6         3666.0       127480.1         11206.0
# ...
